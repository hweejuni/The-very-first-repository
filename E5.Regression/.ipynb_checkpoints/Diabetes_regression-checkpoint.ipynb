# %%
from sklearn.datasets import load_diabetes, load_boston
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np

boston = load_boston()
diabetes = load_diabetes()
print(dir(diabetes))
# Out:
# ['DESCR', 'data', 'data_filename', 'feature_names', 'frame', 'target', 'target_filename']

# %% [markdown]
# age:age in years
# sex
# bmi:body mass index
# bp:average blood pressure
# s1:tc, T-Cells (a type of white blood cells)
# s2:ldl, low-density lipoproteins
# s3:hdl, high-density lipoproteins
# s4:tch, thyroid stimulating hormone
# s5:ltg, lamotrigine
# s6:glu, blood sugar level

# %%
print(diabetes.data.shape)
dfX = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
dfy = pd.DataFrame(diabetes.target, columns=["target"]) # target is a quantitative measure of disease progression one year after baseline
df = pd.concat([dfX, dfy], axis=1)
df
# Out:
# (442, 10)
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
sns.pairplot(df[['s1', 's2', 's3', 's4', 's5']])
plt.show()

# %%
df_X, df_y = diabetes.data[:,:10], diabetes.target

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size=0.2, random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (353, 10) (353,)
# (89, 10) (89,)

# %%
W = np.random.rand(len(X_train[0,:])) # set random weights
b = np.random.rand()

# %%
def model(X, W, b):
    predictions = 0
    for i in range(len(X[0,:])):
        predictions += X[:, i] * W[i]
    predictions += b
    return predictions # predictions = b + x_1*w_1 + w_2*x_2 + ... + w_n*x_n

# %%
def MSE(a, b):
    mse = ((a - b) ** 2).mean() 
    return mse

# %%
def loss(X, W, b, y):
    predictions = model(X, W, b)
    L = MSE(predictions, y)
    return L

# %%
def gradient(X, W, b, y):
    N = len(X)
    y_pred = model(X, W, b)
    dW = 1/N * 2 * X.T.dot(y_pred - y)
    db = 2 * (y_pred - y).mean()
    return dW, db

# %%
dW, db = gradient(X_train, W, b, y_train)
print("dW:", dW)
print("db:", db)
# Out:
# dW: [-1.85019879 -0.10625705 -4.97315056 -3.7090955  -1.30192129 -0.89068573
#   3.1125483  -3.26830823 -4.47416019 -3.50871807]
# db: -306.01740354757965

# %%
LEARNING_RATE = 0.05

# %%
losses = []

for i in range(1, 15001):
    dW, db = gradient(X_train, W, b, y_train)
    W -= LEARNING_RATE * dW
    b -= LEARNING_RATE * db
    L = loss(X_train, W, b, y_train)
    losses.append(L)
    if i % 1000 == 0:
        print('Iteration %d : Loss %0.4f' % (i, L))
# Out:
# Iteration 1000 : Loss 4007.1198
# Iteration 2000 : Loss 3443.6608
# Iteration 3000 : Loss 3214.9351
# Iteration 4000 : Loss 3094.2182
# Iteration 5000 : Loss 3022.9789
# Iteration 6000 : Loss 2979.0834
# Iteration 7000 : Loss 2951.4454
# Iteration 8000 : Loss 2933.7633
# Iteration 9000 : Loss 2922.2799
# Iteration 10000 : Loss 2914.7073
# Iteration 11000 : Loss 2909.6332
# Iteration 12000 : Loss 2906.1755
# Iteration 13000 : Loss 2903.7768
# Iteration 14000 : Loss 2902.0812
# Iteration 15000 : Loss 2900.8582
