# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
dataset_filepath = os.getenv('HOME')+'/aiffel/stock_prediction/data/daily-min-temperatures.csv' 
df = pd.read_csv(dataset_filepath) 
print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True) # index_col: Column(s) to use as the row labels of the DataFrame
print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
ts1 = df['Temp']
print(type(ts1))
ts1.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0    20.7
# 1    17.9
# 2    18.8
# 3    14.6
# 4    15.8
# Name: Temp, dtype: float64

# %% [markdown]
# Analysing stationarity
# ----

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6    # setting the default size of matlab chart to 15,6
plt.plot(ts1)

# %%
ts1[ts1.isna()] # Return a boolean same-sized object indicating if the values are NA.
# Out:
# Series([], Name: Temp, dtype: float64)

# %%
# 결측치가 있다면 이를 보간합니다. 보간 기준은 time을 선택합니다. 
ts1=ts1.interpolate(method='time')
ts1[ts1.isna()]    # 다시 NaN 확인
# Out:
# Series([], Name: Temp, dtype: float64)

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
plot_rolling_statistics(ts1, window=12)

# %% [markdown]
# Can we say this data is stationary? It feels so, but we need to be more concrete to describe it.

# %% [markdown]
# Comparing with different dataset
# ----

# %%
dataset_filepath = os.getenv('HOME')+'/aiffel/stock_prediction/data/airline-passengers.csv' 
df = pd.read_csv(dataset_filepath, index_col='Month', parse_dates=True).fillna(0)  
print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
ts2 = df['Passengers']
plt.plot(ts2)

# %%
plot_rolling_statistics(ts2, window=12)
