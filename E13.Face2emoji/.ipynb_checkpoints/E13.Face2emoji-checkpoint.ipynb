# %% [markdown]
# # 데이터 준비

# %%
import numpy as np
import tqdm
import os
from matplotlib import pyplot as plt
import tensorflow as tf

# %%
train_x = []
train_y = []
eval_x = []
eval_y = []

csv_path = os.getenv('HOME')+'/aiffel/tfjs_mobile/data/fer2013.csv'

with open(csv_path) as f:
  for line in tqdm.tqdm(f.read().splitlines()[1:]):
    emotion, pixels, usage = line.split(',')
    
    x = np.array(pixels.split(' ')).astype(float).reshape(48, 48, 1) / 255
    y = int(emotion)

    if usage == 'PrivateTest':
      eval_x.append(x)
      eval_y.append(y)
    else:
      train_x.append(x)
      train_y.append(y)

print('train : {}, eval :{}'.format(len(train_x), len(eval_x)))
# Out:
# 100%|██████████| 35887/35887 [00:26<00:00, 1367.49it/s]
# train : 32298, eval :3589

# %%
LABELS = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

print(LABELS[train_y[0]])
plt.imshow(train_x[0].reshape([48, 48]), cmap='gray')
# Out:
# Angry

# %% [markdown]
# # Model

# %%
# model 선언 
model = tf.keras.applications.MobileNetV2(input_shape=(48, 48, 1), weights=None, classes=7)

# model.compile
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy()])

#model.fit
history = model.fit(np.stack(train_x),
          tf.keras.utils.to_categorical(train_y),
          epochs=100,
          batch_size=512,
          validation_data=(np.stack(eval_x),
                           tf.keras.utils.to_categorical(eval_y)))
# Out:
# Epoch 1/100
#  2/64 [..............................] - ETA: 6s - loss: 2.2110 - categorical_accuracy: 0.1719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0436s vs `on_train_batch_end` time: 0.0922s). Check your callbacks.
# 64/64 [==============================] - 7s 106ms/step - loss: 1.8366 - categorical_accuracy: 0.2424 - val_loss: 1.9318 - val_categorical_accuracy: 0.2449
# Epoch 2/100
# 64/64 [==============================] - 7s 105ms/step - loss: 1.6979 - categorical_accuracy: 0.3183 - val_loss: 1.9161 - val_categorical_accuracy: 0.2449
# Epoch 3/100
# 64/64 [==============================] - 7s 103ms/step - loss: 1.5724 - categorical_accuracy: 0.3841 - val_loss: 1.8973 - val_categorical_accuracy: 0.2449
# Epoch 4/100
# 64/64 [==============================] - 6s 101ms/step - loss: 1.4805 - categorical_accuracy: 0.4289 - val_loss: 1.8828 - val_categorical_accuracy: 0.1655
# Epoch 5/100
# 64/64 [==============================] - 6s 92ms/step - loss: 1.3963 - categorical_accuracy: 0.4631 - val_loss: 1.8809 - val_categorical_accuracy: 0.1655
# Epoch 6/100
# 64/64 [==============================] - 6s 90ms/step - loss: 1.3271 - categorical_accuracy: 0.4924 - val_loss: 1.8654 - val_categorical_accuracy: 0.1655
# Epoch 7/100
# 64/64 [==============================] - 6s 93ms/step - loss: 1.2757 - categorical_accuracy: 0.5184 - val_loss: 1.8659 - val_categorical_accuracy: 0.1655
# Epoch 8/100
# 64/64 [==============================] - 6s 92ms/step - loss: 1.2058 - categorical_accuracy: 0.5459 - val_loss: 1.8640 - val_categorical_accuracy: 0.1655
# Epoch 9/100
# 64/64 [==============================] - 6s 92ms/step - loss: 1.1696 - categorical_accuracy: 0.5615 - val_loss: 1.8716 - val_categorical_accuracy: 0.1655
# Epoch 10/100
100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2694 - categorical_accuracy: 0.9037 - val_loss: 2.2319 - val_categorical_accuracy: 0.1655
# Epoch 34/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2261 - categorical_accuracy: 0.9206 - val_loss: 2.2823 - val_categorical_accuracy: 0.1655
# Epoch 35/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2981 - categorical_accuracy: 0.8962 - val_loss: 2.2846 - val_categorical_accuracy: 0.1655
# Epoch 36/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2547 - categorical_accuracy: 0.9106 - val_loss: 2.3288 - val_categorical_accuracy: 0.1655
# Epoch 37/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2610 - categorical_accuracy: 0.9069 - val_loss: 2.3403 - val_categorical_accuracy: 0.1655
# Epoch 38/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2123 - categorical_accuracy: 0.9257 - val_loss: 2.3041 - val_categorical_accuracy: 0.1655
# Epoch 39/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.1711 - categorical_accuracy: 0.9408 - val_loss: 2.3404 - val_categorical_accuracy: 0.1655
# Epoch 40/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.1467 - categorical_accuracy: 0.9492 - val_loss: 2.3451 - val_categorical_accuracy: 0.1655
# Epoch 41/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2014 - categorical_accuracy: 0.9316 - val_loss: 2.3263 - val_categorical_accuracy: 0.1655
# Epoch 42/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2019 - categorical_accuracy: 0.9295 - val_loss: 2.3383 - val_categorical_accuracy: 0.1655
# Epoch 43/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2489 - categorical_accuracy: 0.9126 - val_loss: 2.3753 - val_categorical_accuracy: 0.1655
# Epoch 44/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2189 - categorical_accuracy: 0.9238 - val_loss: 2.3680 - val_categorical_accuracy: 0.1655
# Epoch 45/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2485 - categorical_accuracy: 0.9147 - val_loss: 2.4348 - val_categorical_accuracy: 0.1655
# Epoch 46/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2518 - categorical_accuracy: 0.9139 - val_loss: 2.4029 - val_categorical_accuracy: 0.1655
# Epoch 47/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2003 - categorical_accuracy: 0.9298 - val_loss: 2.4920 - val_categorical_accuracy: 0.1655
# Epoch 48/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.1403 - categorical_accuracy: 0.9521 - val_loss: 2.4770 - val_categorical_accuracy: 0.1655
# Epoch 49/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.1154 - categorical_accuracy: 0.9601 - val_loss: 2.5025 - val_categorical_accuracy: 0.1655
# Epoch 50/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.2554 - categorical_accuracy: 0.9112 - val_loss: 2.4386 - val_categorical_accuracy: 0.1655
# Epoch 51/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1515 - categorical_accuracy: 0.9476 - val_loss: 2.5332 - val_categorical_accuracy: 0.1655
# Epoch 52/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1712 - categorical_accuracy: 0.9389 - val_loss: 2.5305 - val_categorical_accuracy: 0.1655
# Epoch 53/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.1762 - categorical_accuracy: 0.9384 - val_loss: 2.5936 - val_categorical_accuracy: 0.1655
# Epoch 54/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1223 - categorical_accuracy: 0.9593 - val_loss: 2.6624 - val_categorical_accuracy: 0.1655
# Epoch 55/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2089 - categorical_accuracy: 0.9281 - val_loss: 2.6992 - val_categorical_accuracy: 0.1655
# Epoch 56/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2064 - categorical_accuracy: 0.9262 - val_loss: 2.6438 - val_categorical_accuracy: 0.1655
# Epoch 57/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1928 - categorical_accuracy: 0.9335 - val_loss: 2.7810 - val_categorical_accuracy: 0.1655
# Epoch 58/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1952 - categorical_accuracy: 0.9305 - val_loss: 2.9309 - val_categorical_accuracy: 0.1655
# Epoch 59/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1257 - categorical_accuracy: 0.9566 - val_loss: 2.7035 - val_categorical_accuracy: 0.1655
# Epoch 60/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1726 - categorical_accuracy: 0.9424 - val_loss: 3.2406 - val_categorical_accuracy: 0.1655
# Epoch 61/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1328 - categorical_accuracy: 0.9539 - val_loss: 3.0637 - val_categorical_accuracy: 0.1655
# Epoch 62/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1343 - categorical_accuracy: 0.9542 - val_loss: 2.8228 - val_categorical_accuracy: 0.1644
# Epoch 63/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1522 - categorical_accuracy: 0.9476 - val_loss: 3.1620 - val_categorical_accuracy: 0.1658
# Epoch 64/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1329 - categorical_accuracy: 0.9543 - val_loss: 3.0356 - val_categorical_accuracy: 0.1649
# Epoch 65/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1536 - categorical_accuracy: 0.9471 - val_loss: 3.5162 - val_categorical_accuracy: 0.1658
# Epoch 66/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.1158 - categorical_accuracy: 0.9602 - val_loss: 3.2879 - val_categorical_accuracy: 0.1700
# Epoch 67/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.0897 - categorical_accuracy: 0.9698 - val_loss: 3.4882 - val_categorical_accuracy: 0.1761
# Epoch 68/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.2348 - categorical_accuracy: 0.9176 - val_loss: 2.8833 - val_categorical_accuracy: 0.1861
# Epoch 69/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.1419 - categorical_accuracy: 0.9518 - val_loss: 4.2707 - val_categorical_accuracy: 0.1811
# Epoch 70/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1102 - categorical_accuracy: 0.9629 - val_loss: 3.7194 - val_categorical_accuracy: 0.1909
# Epoch 71/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2452 - categorical_accuracy: 0.9157 - val_loss: 3.2108 - val_categorical_accuracy: 0.2204
# Epoch 72/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.1633 - categorical_accuracy: 0.9446 - val_loss: 3.4865 - val_categorical_accuracy: 0.2126
# Epoch 73/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1024 - categorical_accuracy: 0.9640 - val_loss: 3.8463 - val_categorical_accuracy: 0.2154
# Epoch 74/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1188 - categorical_accuracy: 0.9602 - val_loss: 3.9240 - val_categorical_accuracy: 0.2340
# Epoch 75/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.0904 - categorical_accuracy: 0.9690 - val_loss: 4.0472 - val_categorical_accuracy: 0.2288
# Epoch 76/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1875 - categorical_accuracy: 0.9368 - val_loss: 4.3531 - val_categorical_accuracy: 0.2460
# Epoch 77/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.2107 - categorical_accuracy: 0.9280 - val_loss: 3.8745 - val_categorical_accuracy: 0.2661
# Epoch 78/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1075 - categorical_accuracy: 0.9626 - val_loss: 3.9014 - val_categorical_accuracy: 0.2987
# Epoch 79/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1447 - categorical_accuracy: 0.9510 - val_loss: 3.8912 - val_categorical_accuracy: 0.3093
# Epoch 80/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.1464 - categorical_accuracy: 0.9494 - val_loss: 3.3971 - val_categorical_accuracy: 0.3430
# Epoch 81/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1892 - categorical_accuracy: 0.9344 - val_loss: 3.5966 - val_categorical_accuracy: 0.3346
# Epoch 82/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1507 - categorical_accuracy: 0.9478 - val_loss: 3.8800 - val_categorical_accuracy: 0.3307
# Epoch 83/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1892 - categorical_accuracy: 0.9342 - val_loss: 3.9945 - val_categorical_accuracy: 0.3413
# Epoch 84/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1179 - categorical_accuracy: 0.9604 - val_loss: 3.5484 - val_categorical_accuracy: 0.3831
# Epoch 85/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.0660 - categorical_accuracy: 0.9786 - val_loss: 3.7867 - val_categorical_accuracy: 0.3837
# Epoch 86/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.0681 - categorical_accuracy: 0.9778 - val_loss: 3.9298 - val_categorical_accuracy: 0.3697
# Epoch 87/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.0701 - categorical_accuracy: 0.9762 - val_loss: 3.9003 - val_categorical_accuracy: 0.3943
# Epoch 88/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1266 - categorical_accuracy: 0.9568 - val_loss: 3.9943 - val_categorical_accuracy: 0.3870
# Epoch 89/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1985 - categorical_accuracy: 0.9311 - val_loss: 4.1490 - val_categorical_accuracy: 0.4140
# Epoch 90/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.0868 - categorical_accuracy: 0.9697 - val_loss: 4.0559 - val_categorical_accuracy: 0.4138
# Epoch 91/100
# 64/64 [==============================] - 7s 102ms/step - loss: 0.0755 - categorical_accuracy: 0.9743 - val_loss: 4.1689 - val_categorical_accuracy: 0.4188
# Epoch 92/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.0931 - categorical_accuracy: 0.9666 - val_loss: 4.1596 - val_categorical_accuracy: 0.4099
# Epoch 93/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.1393 - categorical_accuracy: 0.9518 - val_loss: 4.6129 - val_categorical_accuracy: 0.4185
# Epoch 94/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.0973 - categorical_accuracy: 0.9671 - val_loss: 4.6341 - val_categorical_accuracy: 0.4135
# Epoch 95/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1344 - categorical_accuracy: 0.9545 - val_loss: 4.7329 - val_categorical_accuracy: 0.4255
# Epoch 96/100
# 64/64 [==============================] - 7s 104ms/step - loss: 0.0612 - categorical_accuracy: 0.9792 - val_loss: 4.5464 - val_categorical_accuracy: 0.4285
# Epoch 97/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.0776 - categorical_accuracy: 0.9737 - val_loss: 4.7543 - val_categorical_accuracy: 0.4241
# Epoch 98/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1236 - categorical_accuracy: 0.9573 - val_loss: 4.9548 - val_categorical_accuracy: 0.4090
# Epoch 99/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1277 - categorical_accuracy: 0.9561 - val_loss: 5.0173 - val_categorical_accuracy: 0.4269
# Epoch 100/100
# 64/64 [==============================] - 7s 103ms/step - loss: 0.1131 - categorical_accuracy: 0.9611 - val_loss: 4.9915 - val_categorical_accuracy: 0.4210

# %%
acc = history.history['categorical_accuracy']
val_categorical_acc = history.history['val_categorical_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs = 100
epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_categorical_acc, label='Validation Accuracy')
plt.legend(loc='right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # 모델 convert

# %%
import os
model_path = os.getenv('HOME')+'/aiffel/tfjs_mobile/model.h5'
model.save(model_path)

# %%
tensorflowjs_converter 를 활용해 우리가 저장한 모델을 Tensorflow.js가 활용할 수 있는 형태로 변환해 주어야 합니다. 우선 아래와 같이 tensorflowjs를 설치해 줍니다.

$ pip install tensorflowjs

저장한 모델을 TensorFlow.js로 변환하는 작업은 간단합니다. 터미널에서 tensorflowjs_converter 명령어만 실행하면 됩니다. 

$ cd ~/aiffel/tfjs_mobile
$ tensorflowjs_converter --input_format=keras model.h5 model

이후 ~/aiffel/tfjs_mobile/model 디렉토리에 model.json 및 모델 파일들이 정상적으로 생성되었음을 확인해 봅시다.
